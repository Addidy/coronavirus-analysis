# %%
import utilities as u
import pandas as pd
import sys
import matplotlib.pyplot as plt
import numpy as np
import analyzer as anlzr
# %matplotlib inline

# %%
dl = anlzr.DataDownloader()
# Out:
# Getting latest data...
# Already up to date.

# %%
world = dl.get_analyzer()
world.get_dataframe().tail()
# Out:
#             confirmed_total  death_total  recovered_total  \
# date
# 2020-02-28            84122         2872            36711
# 2020-02-29            86013         2941            39782
# 2020-03-01            88371         2996            42716
# 2020-03-02            90309         3085            45602
# 2020-03-03            92844         3160            48229
#
#             current_infected_total  confirmed_change  death_change  \
# date
# 2020-02-28                   44539            1366.0          58.0
# 2020-02-29                   43290            1891.0          69.0
# 2020-03-01                   42659            2358.0          55.0
# 2020-03-02                   41622            1938.0          89.0
# 2020-03-03                   41455            2535.0          75.0
#
#             recovered_change  current_infected_change  confirmed_change%  \
# date
# 2020-02-28            3434.0                  -2126.0           0.016506
# ...

# %%
world.graph_data()

# %%
world.graph_changes(since_x_days_ago=7)

# %%
world.graph_data(['death_change'])

# %%
world.graph_data(columns=['lethality'], since_x_days_ago=4)

# %%
world.graph_changes_pct(since_x_days_ago=14)

# %%
world.graph_data(['death_change%'], 7)
