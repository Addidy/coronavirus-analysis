# %%
import utilities as u
import pandas as pd
import sys
import matplotlib.pyplot as plt
import numpy as np
import analyzer as anlzr
# %matplotlib inline
# Out:
# C:\Users\Administrator\Anaconda3\envs\coronavirus-analysis\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
dl = anlzr.DataDownloader()
# Out:
# Getting latest data...
# Updating c4547c9..7798d34
# Fast-forward
#  README.md                                          |    2 +
#  .../csse_covid_19_daily_reports/03-23-2020.csv     | 3416 ++++++++++++++++++++
#  .../csse_covid_19_time_series/README.md            |    5 +
#  .../time_series_19-covid-Confirmed.csv             |  990 +++---
#  .../time_series_19-covid-Deaths.csv                |  990 +++---
#  .../time_series_19-covid-Recovered.csv             |  990 +++---
#  .../time_series_covid19_confirmed_global.csv       |  477 +--
#  .../time_series_covid19_deaths_global.csv          |  477 +--
#  8 files changed, 5407 insertions(+), 1940 deletions(-)
#  create mode 100644 csse_covid_19_data/csse_covid_19_daily_reports/03-23-2020.csv

# %%
japan = dl.get_analyzer(include_country_regions=['Japan'])
japan.get_dataframe().tail()
# Out:
#             confirmed_total  death_total  recovered_total  \
# date
# 2020-03-19            924.0         29.0            150.0
# 2020-03-20            963.0         33.0            191.0
# 2020-03-21           1007.0         35.0            232.0
# 2020-03-22           1086.0         40.0            235.0
# 2020-03-23           1086.0         40.0            235.0
#
#             current_infected_total  confirmed_change  death_change  \
# date
# 2020-03-19                   745.0              35.0           0.0
# 2020-03-20                   739.0              39.0           4.0
# 2020-03-21                   740.0              44.0           2.0
# 2020-03-22                   811.0              79.0           5.0
# 2020-03-23                   811.0               0.0           0.0
#
#             recovered_change  current_infected_change  confirmed_change%  \
# date
# 2020-03-19               6.0                     29.0           0.039370
# 2020-03-20              41.0                     -6.0           0.042208
# 2020-03-21              41.0                      1.0           0.045691
# 2020-03-22               3.0                     71.0           0.078451
# 2020-03-23               0.0                      0.0           0.000000
#
#             death_change%  recovered_change%  current_infected_change%  \
# date
# 2020-03-19       0.000000           0.041667                  0.040503
# 2020-03-20       0.137931           0.273333                 -0.008054
# 2020-03-21       0.060606           0.214660                  0.001353
# 2020-03-22       0.142857           0.012931                  0.095946
# 2020-03-23       0.000000           0.000000                  0.000000
#
#             confirmed_change%5a  death_change%5a  recovered_change%5a  \
# date
# 2020-03-19             0.036967         0.060269             0.052401
# 2020-03-20             0.028332         0.087856             0.107068
# 2020-03-21             0.040808         0.054522             0.105932
# 2020-03-22             0.043650         0.068279             0.108518
# 2020-03-23             0.041144         0.068279             0.108518
#
#             current_infected_change%5a  lethality
# date
# 2020-03-19                    0.034795   0.193333
# 2020-03-20                    0.012331   0.172775
# 2020-03-21                    0.025477   0.150862
# 2020-03-22                    0.029070   0.170213
# 2020-03-23                    0.025950   0.170213

# %%
japan.graph_data()

# %%
japan.graph_changes()

# %%
u.graph_financial_data('^N225')

# %%
japan.graph_data(['death_total'])

# %%
japan.graph_data(['death_change'])

# %%
japan.graph_changes_pct(since_x_days_ago=14)

# %%
japan.graph_changes_pct_avg(since_x_days_ago=14)
