# %%
import utilities as u
import pandas as pd
import sys
import matplotlib.pyplot as plt
import numpy as np
import analyzer as anlzr
# %matplotlib inline

# %%
dl = anlzr.DataDownloader()
# Out:
# Getting latest data...
# Already up to date.

# %%
top_economies = ['US', 'Japan', 'Germany', 'India', 'United Kingdom', 'France', 'Italy', 'Brazil', 'Canada']

# %%
world = dl.get_analyzer(include_country_regions=top_economies)
world.get_dataframe().tail()
# Out:
#             confirmed_total  death_total  recovered_total  \
# date
# 2020-02-29             1643           37              122
# 2020-03-01             2315           43              159
# 2020-03-02             2795           67              225
# 2020-03-03             3354           96              248
# 2020-03-04             4185          128              364
#
#             current_infected_total  confirmed_change  death_change  \
# date
# 2020-02-29                    1484             342.0          10.0
# 2020-03-01                    2113             672.0           6.0
# 2020-03-02                    2503             480.0          24.0
# 2020-03-03                    3010             559.0          29.0
# 2020-03-04                    3693             831.0          32.0
#
#             recovered_change  current_infected_change  confirmed_change%  \
# date
# 2020-02-29              11.0                    321.0           0.262875
# 2020-03-01              37.0                    629.0           0.409008
# 2020-03-02              66.0                    390.0           0.207343
# 2020-03-03              23.0                    507.0           0.200000
# 2020-03-04             116.0                    683.0           0.247764
#
#             death_change%  recovered_change%  current_infected_change%  \
# date
# 2020-02-29       0.370370           0.099099                  0.276010
# 2020-03-01       0.162162           0.303279                  0.423854
# 2020-03-02       0.558140           0.415094                  0.184572
# 2020-03-03       0.432836           0.102222                  0.202557
# 2020-03-04       0.333333           0.467742                  0.226910
#
#             confirmed_change%3a  death_change%3a  recovered_change%3a  \
# date
# 2020-02-29             0.292324         0.328779             0.224402
# 2020-03-01             0.322118         0.285986             0.287721
# 2020-03-02             0.285583         0.316146             0.208955
# 2020-03-03             0.269807         0.380877             0.229924
# 2020-03-04             0.266029         0.371618             0.322084
#
#             current_infected_change%3a  lethality
# date
# 2020-02-29                    0.301107   0.303279
# 2020-03-01                    0.327920   0.270440
# 2020-03-02                    0.294884   0.297778
# 2020-03-03                    0.271748   0.387097
# 2020-03-04                    0.259473   0.351648

# %%
world.graph_data()

# %%
world.graph_changes(since_x_days_ago=10)

# %%
world.graph_data(['death_change'])

# %%
world.graph_data(columns=['lethality'], since_x_days_ago=4)

# %%
world.graph_changes_pct(since_x_days_ago=14)

# %%
world.graph_changes_pct_avg()

# %%
world.graph_data(['death_change%'], 7)
