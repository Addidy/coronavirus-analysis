# %%
import utilities as u
import pandas as pd
import sys
import matplotlib.pyplot as plt
import numpy as np
import analyzer as anlzr
# %matplotlib inline

# %%
dl = anlzr.DataDownloader()
# Out:
# No Data found.
# Performing first time setup...
# Downloading Data... (This can take a minute)
# Setup Complete.

# %%
data_w_china = dl.get_analyzer()
data_w_china.get_dataframe().tail()
# Out:
#             confirmed_total  death_total  recovered_total  confirmed_change  \
# date
# 2020-02-28            84122         2872            36711            1366.0
# 2020-02-29            86013         2941            39782            1891.0
# 2020-03-01            88371         2996            42716            2358.0
# 2020-03-02            90309         3085            45602            1938.0
# 2020-03-03            92844         3160            48229            2535.0
#
#             death_change  recovered_change  current_infected_total  \
# date
# 2020-02-28          58.0            3434.0                   44539
# 2020-02-29          69.0            3071.0                   43290
# 2020-03-01          55.0            2934.0                   42659
# 2020-03-02          89.0            2886.0                   41622
# 2020-03-03          75.0            2627.0                   41455
#
#             current_infected_change  current_infected_change%  lethality
# date
# 2020-02-28                  -2126.0                 -0.045559   0.078233
# 2020-02-29                  -1249.0                 -0.028043   0.073928
# 2020-03-01                   -631.0                 -0.014576   0.070138
# 2020-03-02                  -1037.0                 -0.024309   0.067651
# 2020-03-03                   -167.0                 -0.004012   0.065521

# %%
data_w_china.graph_data(['death_change'])

# %%
data_w_china.graph_data(['lethality'])

# %%
data_w_china.graph_data()

# %%
data = dl.get_analyzer(exclude_country_regions=['Mainland China'])
data.get_dataframe().tail()
# Out:
#             confirmed_total  death_total  recovered_total  confirmed_change  \
# date
# 2020-02-28             5298           84              420            1040.0
# 2020-02-29             6762          106              503            1464.0
# 2020-03-01             8545          126              598            1783.0
# 2020-03-02            10283          173              792            1738.0
# 2020-03-03            12693          215              825            2410.0
#
#             death_change  recovered_change  current_infected_total  \
# date
# 2020-02-28          14.0              41.0                    4794
# 2020-02-29          22.0              83.0                    6153
# 2020-03-01          20.0              95.0                    7821
# 2020-03-02          47.0             194.0                    9318
# 2020-03-03          42.0              33.0                   11653
#
#             current_infected_change  current_infected_change%  lethality
# date
# 2020-02-28                    985.0                  0.258598   0.200000
# 2020-02-29                   1359.0                  0.283479   0.210736
# 2020-03-01                   1668.0                  0.271087   0.210702
# 2020-03-02                   1497.0                  0.191408   0.218434
# 2020-03-03                   2335.0                  0.250590   0.260606

# %%
data.graph_data()

# %%
data.graph_data(['recovered_total', 'death_total'])

# %%
data.graph_data(['current_infected_change'])
data.graph_data(['current_infected_change%'])
data.graph_data(['death_change'])
data.graph_data(['lethality'])

# %%
UK = dl.get_analyzer(include_country_regions=['UK'], exclude_country_regions=['Mainland China'])
UK.get_dataframe().tail()
# Out:
#             confirmed_total  death_total  recovered_total  confirmed_change  \
# date
# 2020-02-28               20            0                8               5.0
# 2020-02-29               23            0                8               3.0
# 2020-03-01               36            0                8              13.0
# 2020-03-02               40            0                8               4.0
# 2020-03-03               51            0                8              11.0
#
#             death_change  recovered_change  current_infected_total  \
# date
# 2020-02-28           0.0               0.0                      12
# 2020-02-29           0.0               0.0                      15
# 2020-03-01           0.0               0.0                      28
# 2020-03-02           0.0               0.0                      32
# 2020-03-03           0.0               0.0                      43
#
#             current_infected_change  current_infected_change%  lethality
# date
# 2020-02-28                      5.0                  0.714286        0.0
# 2020-02-29                      3.0                  0.250000        0.0
# 2020-03-01                     13.0                  0.866667        0.0
# 2020-03-02                      4.0                  0.142857        0.0
# 2020-03-03                     11.0                  0.343750        0.0

# %%
UK.graph_data()
UK.graph_data(['current_infected_change'])
UK.graph_data(['current_infected_change%'])
