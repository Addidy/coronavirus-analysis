# %%
import utilities as u
import pandas as pd
import sys
import matplotlib.pyplot as plt
import numpy as np
import analyzer as anlzr
# %matplotlib inline
# Out:
# C:\Users\Administrator\Anaconda3\envs\coronavirus-analysis\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
dl = anlzr.DataDownloader()
# Out:
# Getting latest data...
# Already up to date.

# %%
data_w_china = dl.get_analyzer()
data_w_china.get_dataframe().tail()
# Out:
#             confirmed_total  death_total  recovered_total  \
# date
# 2020-03-05            97885         3348            53797
# 2020-03-06           101799         3460            55866
# 2020-03-07           105835         3558            58359
# 2020-03-08           109814         3803            60695
# 2020-03-09           113583         3996            62512
#
#             current_infected_total  confirmed_change  death_change  \
# date
# 2020-03-05                   40740            2762.0          94.0
# 2020-03-06                   42473            3914.0         112.0
# 2020-03-07                   43918            4036.0          98.0
# 2020-03-08                   45316            3979.0         245.0
# 2020-03-09                   47075            3769.0         193.0
#
#             recovered_change  current_infected_change  confirmed_change%  \
# date
# 2020-03-05            2626.0                     42.0           0.029036
# ...

# %%
data_w_china.graph_data(['death_change'])

# %%
data_w_china.graph_data(['lethality'])

# %%
data_w_china.graph_data()

# %%
data = dl.get_analyzer(exclude_country_regions=['Mainland China'])
data.get_dataframe().tail()
# Out:
#             confirmed_total  death_total  recovered_total  \
# date
# 2020-03-05            17463          335             1557
# 2020-03-06            21226          418             1978
# 2020-03-07            25183          488             2881
# 2020-03-08            29115          706             3375
# 2020-03-09            32848          876             3777
#
#             current_infected_total  confirmed_change  death_change  \
# date
# 2020-03-05                   15571            2611.0          62.0
# 2020-03-06                   18830            3763.0          83.0
# 2020-03-07                   21814            3957.0          70.0
# 2020-03-08                   25034            3932.0         218.0
# 2020-03-09                   28195            3733.0         170.0
#
#             recovered_change  current_infected_change  confirmed_change%  \
# date
# 2020-03-05             341.0                   2208.0           0.175801
# ...

# %%
data.graph_data()

# %%
data.graph_data(['recovered_total', 'death_total'])

# %%
data.graph_data(['current_infected_change'])
data.graph_data(['current_infected_change%'])
data.graph_data(['death_change'])
data.graph_data(['lethality'])

# %%
UK = dl.get_analyzer(include_country_regions=['UK'], exclude_country_regions=['Mainland China'])
UK.get_dataframe().tail()
# Out:
#             confirmed_total  death_total  recovered_total  \
# date
# 2020-03-05              115            1                8
# 2020-03-06              163            2                8
# 2020-03-07              206            2               18
# 2020-03-08              273            3               18
# 2020-03-09              321            4               18
#
#             current_infected_total  confirmed_change  death_change  \
# date
# 2020-03-05                     106              30.0           1.0
# 2020-03-06                     153              48.0           1.0
# 2020-03-07                     186              43.0           0.0
# 2020-03-08                     252              67.0           1.0
# 2020-03-09                     299              48.0           1.0
#
#             recovered_change  current_infected_change  confirmed_change%  \
# date
# 2020-03-05               0.0                     29.0           0.352941
# ...

# %%
UK.graph_data()
UK.graph_data(['current_infected_change'])
UK.graph_data(['current_infected_change%'])
